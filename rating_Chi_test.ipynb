# %% [markdown]
# **Are ratings and continent dependent on each other ?**

# %%
import pandas as pd 
import numpy as np
from scipy import stats as st
from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %% [markdown]
# **Prepare Data that is rating and continent**

# %%
all_rating_processed = pd.read_csv('all_rating_processed.csv', sep = '\t', encoding='utf-8')

# %%
all_rating_processed['Country'].unique()
# Out:
# array(['Undefined', 'UnitedStates', 'France', 'Poland', 'Belgium',
#        'UnitedKingdom', 'Sweden', 'Finland', 'Austria', 'Norway',
#        'Germany', 'Netherlands', 'Canada', 'Switzerland', 'Italy',
#        'Russia', 'Spain', 'Portugal', 'Lithuania', 'Denmark', 'England',
#        'Scotland', 'Ireland', 'Hungary', 'Greece', 'Bulgaria', 'Croatia',
#        'Belarus', 'Serbia', 'Slovakia', 'Ukraine', 'Estonia',
#        'Luxembourg', 'CzechRepublic', 'Turkey', 'Latvia',
#        'BosniaandHerzegovina', 'FaroeIslands'], dtype=object)

# %%
all_rating_processed['Continent'].unique()
# Out:
# array(['Undefined', 'NorthAmerica', 'Europe'], dtype=object)

# %%
all_rating_processed.head(5)
# Out:
#    Unnamed: 0   Game_name               Gamer     Date   Rating  \
# 0           0  Gloomhaven            guile678  Mar2020  8.70000
# 1           1  Gloomhaven  purplephoenixgames  Mar2020 -0.00001
# 2           2  Gloomhaven             oneover  Mar2020  8.00000
# 3           3  Gloomhaven               MrKek  Mar2020 -0.00001
# 4           4  Gloomhaven      queerchameleon  Mar2020  4.00000
#
#                        Location                   file       Country  \
# 0                     Undefined  0_174430_20_pages.csv     Undefined
# 1   Milan,Illinois·UnitedStates  0_174430_20_pages.csv  UnitedStates
# 2                     Undefined  0_174430_20_pages.csv     Undefined
# 3  Honolulu,Hawaii·UnitedStates  0_174430_20_pages.csv  UnitedStates
# 4   GroveCity,Ohio·UnitedStates  0_174430_20_pages.csv  UnitedStates
#
#       Continent
# 0     Undefined
# 1  NorthAmerica
# 2     Undefined
# 3  NorthAmerica
# 4  NorthAmerica

# %%
all_rating_processed.drop(['Unnamed: 0','Location','file'], axis=1, inplace = True)
all_rating_processed.describe()
# Out:
#               Rating
# count  908577.000000
# mean        6.970318
# std         2.325704
# min        -0.000010
# 25%         6.500000
# 50%         7.500000
# 75%         8.000000
# max        10.000000

# %%
NA_data = all_rating_processed[all_rating_processed['Continent'] =='NorthAmerica']
Undef_data = all_rating_processed[all_rating_processed['Continent'] =='Undefined']
EU_data = all_rating_processed[all_rating_processed['Continent'] =='Europe']

# %%
all_rating_processed.dtypes
# Out:
# Game_name     object
# Gamer         object
# Date          object
# Rating       float64
# Country       object
# Continent     object
# dtype: object

# %% [markdown]
# **Contingency Table showing correlation between Rating and Continent**

# %%
contigency_data = pd.crosstab(all_rating_processed['Rating'],
                            all_rating_processed['Continent'], 
                               margins = False)
contigency_data
# Out:
# Continent  Europe  NorthAmerica  Undefined
# Rating
# -0.00001    19108         34183       8982
#  1.00000      665           755        709
#  1.10000        1             5         12
#  1.20000        0             1          0
#  1.30000        1             2          1
#  1.40000        1             1          2
#  1.50000       11            11          8
#  1.60000        2             0          0
#  1.70000        0             0          2
#  1.80000        2             2          1
#  1.90000        2             1          0
#  2.00000      938          1251        583
#  2.10000        3             3          3
#  2.20000        4             5          3
#  2.30000        1             6          0
#  2.40000        2             1          1
#  2.50000       32            68         13
#  2.60000        4             3          1
#  2.70000        1             1          0
#  2.80000        5             9          2
#  2.90000        2             3          2
#  3.00000     2301          2897       1327
#  3.10000       10            10          4
#  3.20000        4             7          5
#  3.30000        5            81          7
#  3.40000        3             7          8
#  3.50000      137           164         41
#  3.60000        5             5          5
#  3.70000        2             8          4
#  3.80000       10            13          7
# ...           ...           ...        ...
#  7.10000      567           543        284
#  7.20000     1008           876        496
#  7.30000     1284          1606        662
#  7.40000      873           761        423
#  7.50000    17741         20463       7816
#  7.60000      878           755        403
#  7.70000      961           868        453
#  7.80000     2044          2401       1067
#  7.90000      800           824        396
#  8.00000    78516         84029      39464
#  8.10000      607           663        312
#  8.20000      918           878        489
#  8.30000      991          1299        528
#  8.40000      596           633        294
#  8.50000    10062         12371       5120
#  8.60000      496           492        288
#  8.70000      490           560        283
#  8.80000      769          1133        449
#  8.90000      355           453        170
#  9.00000    38583         41685      21824
#  9.10000      274           340        140
#  9.20000      285           364        191
#  9.30000      295           468        186
#  9.40000      169           219         96
#  9.50000     2544          3398       1475
#  9.60000      158           187         78
#  9.70000      114           148         97
#  9.80000      176           302        114
#  9.90000      138           174         71
#  10.00000   17303         19237      12742
#
# [92 rows x 3 columns]

# %% [markdown]
# **Get chi-square value , p-value, degrees of freedom, expected frequencies using the function chi2_contingency**

# %%
stat, p, dof, expected = chi2_contingency(contigency_data)
print("Chi-Square Test Statistic",stat)
print("P-value", p)
print("degree of freedom", dof)
print("expected",expected)
# Out:
# Chi-Square Test Statistic 7414.277773903627
# P-value 0.0
# degree of freedom 182
# expected [[2.34815454e+04 2.69564750e+04 1.18349796e+04]
#  [8.02791100e+02 9.21592588e+02 4.04616312e+02]
#  [6.78733668e+00 7.79176448e+00 3.42089883e+00]
#  [3.77074260e-01 4.32875805e-01 1.90049935e-01]
#  [1.50829704e+00 1.73150322e+00 7.60199741e-01]
#  [1.50829704e+00 1.73150322e+00 7.60199741e-01]
#  [1.13122278e+01 1.29862741e+01 5.70149806e+00]
#  [7.54148520e-01 8.65751609e-01 3.80099870e-01]
#  [7.54148520e-01 8.65751609e-01 3.80099870e-01]
#  [1.88537130e+00 2.16437902e+00 9.50249676e-01]
#  [1.13122278e+00 1.29862741e+00 5.70149806e-01]
#  [1.04524985e+03 1.19993173e+03 5.26818420e+02]
#  [3.39366834e+00 3.89588224e+00 1.71044942e+00]
#  [4.52489112e+00 5.19450966e+00 2.28059922e+00]
#  [4.88311167e+02 5.60574167e+02 2.46114666e+02]
#  [7.17934308e+04 8.24178217e+04 3.61847475e+04]
#  [5.25641519e+02 6.03428872e+02 2.64929610e+02]
#  [8.97436739e+02 1.03024442e+03 4.52318846e+02]
#  [1.33936777e+03 1.53757486e+03 6.75057370e+02]
#  [7.75641753e+02 8.90425530e+02 3.90932717e+02]
#  [1.73529574e+04 1.99209445e+04 8.74609802e+03]
#  [7.67723194e+02 8.81335138e+02 3.86941668e+02]
#  [8.60483462e+02 9.87822586e+02 4.33693952e+02]
#  [2.07843332e+03 2.38601144e+03 1.04755524e+03]
#  [7.61690005e+02 8.74409125e+02 3.83900869e+02]
#  [7.61723942e+04 8.74448084e+04 3.83917974e+04]
#  [5.96531479e+02 6.84809523e+02 3.00658998e+02]
#  [8.61614684e+02 9.89121214e+02 4.34264102e+02]
#  [1.06259526e+03 1.21984402e+03 5.35560717e+02]
#  [5.74284098e+02 6.59269851e+02 2.89446051e+02]
#  [1.03895271e+04 1.19270270e+04 5.23644587e+03]
#  [4.81146756e+02 5.52349527e+02 2.42503717e+02]
#  [5.02639989e+02 5.77023448e+02 2.53336564e+02]
#  [8.86501585e+02 1.01769102e+03 4.46807398e+02]
#  [3.68778626e+02 4.23352537e+02 1.85868837e+02]
#  [3.84962654e+04 4.41931567e+04 1.94025780e+04]
#  [2.84313992e+02 3.26388357e+02 1.43297651e+02]
#  [3.16742378e+02 3.63615676e+02 1.59641946e+02]
#  [3.57843473e+02 4.10799139e+02 1.80357389e+02]
#  [1.82503942e+02 2.09511889e+02 9.19841687e+01]
#  [2.79675979e+03 3.21063984e+03 1.40960037e+03]
#  [1.59502412e+02 1.83106465e+02 8.03911226e+01]
#  [1.35369659e+02 1.55402414e+02 6.82279267e+01]
#  [2.23227962e+02 2.56262476e+02 1.12509562e+02]
#  [1.44419442e+02 1.65791433e+02 7.27891252e+01]
#  [1.85829737e+04 2.13329854e+04 9.36604091e+03]]

# %% [markdown]
# **select significance value as alpha = 0.05 and determine whether to reject or keep your null hypothesis**

# %%
alpha = 0.05
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Variables are associated (reject H0)')
else:
    print('Variables are not associated(fail to reject H0)')
# Out:
# significance=0.050, p=0.000
# Variables are associated (reject H0)

# %% [markdown]
# **chi-squared test with similar proportions**

# %% [markdown]
# **interpret test-statistic**

# %%
prob = 0.95
critical = chi2.ppf(prob, dof)
print('probability=%.3f, critical=%.3f, stat=%.3f' % (prob, critical, stat))
if abs(stat) >= critical:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# probability=0.950, critical=214.477, stat=7414.278
# Dependent (reject H0)

# %% [markdown]
# **interpret p-value**

# %%
alpha = 1.0 - prob
print('significance=%.3f, p=%.3f' % (alpha, p))
if p <= alpha:
    print('Dependent (reject H0)')
else:
    print('Independent (fail to reject H0)')
# Out:
# significance=0.050, p=0.000
# Dependent (reject H0)

# %% [markdown]
# **Chi-squared test statistic, sample size, and minimum of rows and columns**

# %%
X2 = chi2_contingency(contigency_data, correction=False)[0]
n = np.sum(contigency_data)
minDim = min(contigency_data.shape)-1

# %% [markdown]
# **calculate Cramer's V**

# %%
V = np.sqrt((X2/n) / minDim)
print(V)
# Out:
# Continent
# Europe          0.104022
# NorthAmerica    0.097086
# Undefined       0.146523
# dtype: float64
