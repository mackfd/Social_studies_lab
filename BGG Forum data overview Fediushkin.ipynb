# %%
import pandas as pd

# %%
df = pd.read_csv('D:/Uni Passau/Semester 2/5. Social science/archive/bgg_GameItem.csv')
# Out:
# c:\users\armit\python\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#        bgg_id                             name    year game_type  \
# 0           1                       Die Macher  1986.0      5497
# 1           2                     Dragonmaster  1981.0      5497
# 2           3                          Samurai  1998.0      5497
# 3           4                   Tal der Könige  1992.0       NaN
# 4           5                          Acquire  1964.0      5497
# ...       ...                              ...     ...       ...
# 99247  329394             Zurvivors Cooperação  2021.0       NaN
# 99248  329416                      1823 France  2021.0       NaN
# 99249  329429  Streets Of Steel: Rush 'N Scare  2020.0       NaN
# 99250  329450                          Equinox  2021.0       NaN
# 99251  329455                      Ronchonchon  2021.0       NaN
#
#                  designer              artist  \
# 0                       1          12517,4959
# 1                    8384               12424
# ...

# %%
df.describe()
# Out:
#               bgg_id          year   min_players   max_players  \
# count   99252.000000  90210.000000  97418.000000  93886.000000
# mean   126410.100401   1999.320474      2.038730      6.608557
# std    103485.523806     72.201449      0.815756     52.827356
# min         1.000000  -3500.000000      1.000000      1.000000
# 25%     28504.500000   1995.000000      2.000000      4.000000
# 50%    112292.000000   2009.000000      2.000000      4.000000
# 75%    212971.250000   2016.000000      2.000000      6.000000
# max    329455.000000   2023.000000     50.000000  11299.000000
#
#        min_players_rec  max_players_rec  min_players_best  max_players_best  \
# count     97418.000000     93886.000000      97418.000000      93886.000000
# mean          2.043821         6.589758          2.075315          6.566666
# std           0.821430        52.816641          0.859348         52.817368
# min           1.000000         1.000000          1.000000          1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99252 entries, 0 to 99251
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   bgg_id               99252 non-null  int64
#  1   name                 99252 non-null  object
#  2   year                 90210 non-null  float64
#  3   game_type            21621 non-null  object
#  4   designer             84849 non-null  object
#  5   artist               40447 non-null  object
#  6   publisher            99240 non-null  object
#  7   min_players          97418 non-null  float64
#  8   max_players          93886 non-null  float64
#  9   min_players_rec      97418 non-null  float64
#  10  max_players_rec      93886 non-null  float64
#  11  min_players_best     97418 non-null  float64
#  12  max_players_best     93886 non-null  float64
#  13  min_age              77274 non-null  float64
#  14  min_age_rec          891 non-null    float64
# ...

# %%
bga = pd.read_csv('D:/Uni Passau/Semester 2/Social science/archive/bga_GameItem.csv')

# %%
bga.head()
# Out:
#    bgg_id                              name    year  game_type  \
# 0     NaN  Clank! A Deck-Building Adventure  2012.0        NaN
# 1     NaN                         El Grande  1995.0        NaN
# 2     NaN      Gloomhaven: Jaws of the Lion  2020.0        NaN
# 3     NaN                Android: Netrunner  2012.0        NaN
# 4     NaN                       Rum & Bones  2015.0        NaN
#
#                              designer  \
# 0  id,num_games,score,game,url,images
# 1  id,num_games,score,game,url,images
# 2  id,num_games,score,game,url,images
# 3  id,num_games,score,game,url,images
# 4  id,num_games,score,game,url,images
#
#                                               artist  \
# 0  Rayph Beisner,Raul Ramos,Nate Storm,Derrick He...
# 1                                     Doris Matthäus
# 2                                   Alexandr Elichev
# 3  Bruno Balixa,Ralph Beisner,Del Borovic,Gong St...
# 4                           Jose David Lanza Cebrian
#
# ...

# %%
bga.describe()
# Out:
#        bgg_id         year  game_type  min_players  max_players  \
# count     0.0  1132.000000        0.0  1146.000000  1146.000000
# mean      NaN  2009.576855        NaN     1.911867     5.128272
# std       NaN    28.140206        NaN     0.778588     5.462388
# min       NaN  1475.000000        NaN     1.000000     1.000000
# 25%       NaN  2010.000000        NaN     1.000000     4.000000
# 50%       NaN  2015.000000        NaN     2.000000     4.000000
# 75%       NaN  2018.000000        NaN     2.000000     5.000000
# max       NaN  2021.000000        NaN     8.000000   100.000000
#
#        min_players_rec  max_players_rec  min_players_best  max_players_best  \
# count              0.0              0.0               0.0               0.0
# mean               NaN              NaN               NaN               NaN
# std                NaN              NaN               NaN               NaN
# min                NaN              NaN               NaN               NaN
# ...

# %%
dbpedia = pd.read_csv('D:/Uni Passau/Semester 2/Social science/archive/dbpedia_GameItem.csv')

# %%
dbpedia
# Out:
#       bgg_id                    name    year  game_type          designer  \
# 0        NaN                   *Star     NaN        NaN               NaN
# 1        NaN                   .hack     NaN        NaN               NaN
# 2     4550.0  1000 Blank White Cards  1996.0        NaN               NaN
# 3        NaN   100 mexicanos dijeron     NaN        NaN               NaN
# 4        NaN     1313 Dead End Drive     NaN        NaN               NaN
# ...      ...                     ...     ...        ...               ...
# 3910     NaN                    Zyll     NaN        NaN               NaN
# 3911     NaN                   ZÈRTZ     NaN        NaN  Kris Burm,크리스 뷔름
# 3912     NaN              Ætherverse     NaN        NaN               NaN
# 3913     NaN                  Écarté     NaN        NaN               NaN
# 3914     NaN               Ô ăn quan     NaN        NaN               NaN
#
#       artist                                          publisher  min_players  \
# ...

# %%
luding = pd.read_csv('D:/Uni Passau/Semester 2/Social science/archive/luding_GameItem.csv')

# %%
luding
# Out:
#        bgg_id                    name    year game_type  \
# 0      6706.0                  Xerxes  1973.0     Board
# 1         NaN      Das Krokodil-Spiel  1987.0     Board
# 2         NaN                Conquest  1987.0     Board
# 3         NaN                    Momo  1987.0     Board
# 4         NaN             Drachenfels  1986.0     Board
# ...       ...                     ...     ...       ...
# 31906     NaN  Welcome to the Dungeon     NaN     Board
# 31907     NaN                Verkopft     NaN     Board
# 31908     NaN          Kurz vor Knapp     NaN     Board
# 31909     NaN       Schotten Totten 2     NaN     Board
# 31910     NaN               Mariposas  2020.0     Board
#
#                              designer                 artist  \
# 0                         Kurt Heuser                    NaN
# 1                    Johann Rüttinger                    NaN
# 2                        Donald Benge                    NaN
# ...

# %%
spielen = pd.read_csv('D:/Uni Passau/Semester 2/Social science/archive/spielen_GameItem.csv')

# %%
spielen.describe()
# Out:
#        bgg_id         year  game_type  min_players  max_players  \
# count     0.0  5538.000000        0.0  5533.000000  5059.000000
# mean      NaN  2004.787468        NaN     2.066871     7.063254
# std       NaN   127.833465        NaN     0.680168    12.859491
# min       NaN -2000.000000        NaN     1.000000     2.000000
# 25%       NaN  2008.000000        NaN     2.000000     4.000000
# 50%       NaN  2014.000000        NaN     2.000000     5.000000
# 75%       NaN  2017.000000        NaN     2.000000     6.000000
# max       NaN  2020.000000        NaN    15.000000   100.000000
#
#        min_players_rec  max_players_rec  min_players_best  max_players_best  \
# count              0.0              0.0               0.0               0.0
# mean               NaN              NaN               NaN               NaN
# std                NaN              NaN               NaN               NaN
# min                NaN              NaN               NaN               NaN
# ...
